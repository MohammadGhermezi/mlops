# %%
import pandas as pd

df=pd.read_csv("../data/raw/german_credit_data.csv")

df.head()
# Out:
#    laufkont  laufzeit  moral  verw  hoehe  sparkont  beszeit  rate  famges  \
# 0         1        18      4     2   1049         1        2     4       2
# 1         1         9      4     0   2799         1        3     2       3
# 2         2        12      2     9    841         2        4     2       2
# 3         1        12      4     0   2122         1        3     3       3
# 4         1        12      4     0   2171         1        3     4       3
#
#    buerge  ...  verm  alter  weitkred  wohn  bishkred  beruf  pers  telef  \
# 0       1  ...     2     21         3     1         1      3     2      1
# 1       1  ...     1     36         3     1         2      3     1      1
# 2       1  ...     1     23         3     1         1      2     2      1
# 3       1  ...     1     39         3     1         2      2     1      1
# 4       1  ...     2     38         1     2         2      2     2      1
#
#    gastarb  kredit
# 0        2       1
# 1        2       1
# ...

# %%
df.isnull().sum()
# Out:
# laufkont    0
# laufzeit    0
# moral       0
# verw        0
# hoehe       0
# sparkont    0
# beszeit     0
# rate        0
# famges      0
# buerge      0
# wohnzeit    0
# verm        0
# alter       0
# weitkred    0
# wohn        0
# bishkred    0
# beruf       0
# pers        0
# telef       0
# gastarb     0
# kredit      0
# dtype: int64

# %%
df["kredit"].value_counts()
# Out:
# kredit
# 1    700
# 0    300
# Name: count, dtype: int64

# %%
df["kredit"].value_counts(normalize=True)
# Out:
# kredit
# 1    0.7
# 0    0.3
# Name: proportion, dtype: float64

# %%
df.dtypes
# Out:
# laufkont    int64
# laufzeit    int64
# moral       int64
# verw        int64
# hoehe       int64
# sparkont    int64
# beszeit     int64
# rate        int64
# famges      int64
# buerge      int64
# wohnzeit    int64
# verm        int64
# alter       int64
# weitkred    int64
# wohn        int64
# bishkred    int64
# beruf       int64
# pers        int64
# telef       int64
# gastarb     int64
# kredit      int64
# dtype: object

# %%
df["alter"].describe()
# Out:
# count    1000.00000
# mean       35.54200
# std        11.35267
# min        19.00000
# 25%        27.00000
# 50%        33.00000
# 75%        42.00000
# max        75.00000
# Name: alter, dtype: float64

# %%
df["hoehe"].describe()
# Out:
# count     1000.00000
# mean      3271.24800
# std       2822.75176
# min        250.00000
# 25%       1365.50000
# 50%       2319.50000
# 75%       3972.25000
# max      18424.00000
# Name: hoehe, dtype: float64

# %%
df["laufzeit"].describe()
# Out:
# count    1000.000000
# mean       20.903000
# std        12.058814
# min         4.000000
# 25%        12.000000
# 50%        18.000000
# 75%        24.000000
# max        72.000000
# Name: laufzeit, dtype: float64

# %%
cor=df.corr(numeric_only=True)
cor["kredit"].sort_values(ascending=False)
# Out:
# kredit      1.000000
# laufkont    0.350847
# moral       0.228785
# sparkont    0.178943
# beszeit     0.116002
# weitkred    0.109844
# alter       0.091272
# famges      0.088184
# bishkred    0.045732
# telef       0.036466
# buerge      0.025137
# wohn        0.018119
# wohnzeit   -0.002967
# pers       -0.003015
# verw       -0.017979
# beruf      -0.032735
# rate       -0.072404
# gastarb    -0.082079
# verm       -0.142612
# hoehe      -0.154740
# laufzeit   -0.214927
# Name: kredit, dtype: float64

# %%
df.columns
# Out:
# Index(['laufkont', 'laufzeit', 'moral', 'verw', 'hoehe', 'sparkont', 'beszeit',
#        'rate', 'famges', 'buerge', 'wohnzeit', 'verm', 'alter', 'weitkred',
#        'wohn', 'bishkred', 'beruf', 'pers', 'telef', 'gastarb', 'kredit'],
#       dtype='str')

# %%
import matplotlib.pyplot as plt

df["kredit"].value_counts().plot(kind="bar")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df["alter"].hist(bins=20)

plt.show()

# %%
df["hoehe"].hist(bins=20)

plt.show()

# %%
df["laufzeit"].hist(bins=20)

plt.show()

# %%
df=df.rename(columns={
    "laufkont": "checking_account",
        "laufzeit": "loan_duration",
        "moral": "credit_history",
        "verw": "loan_purpose",
        "hoehe": "credit_amount",
        "sparkont": "savings_account",
        "beszeit": "employment_duration",
        "rate": "installment_rate",
        "famges": "personal_status",
        "buerge": "guarantors",
        "wohnzeit": "residence_duration",
        "verm": "assets",
        "alter": "age",
        "weitkred": "other_credits",
        "wohn": "housing",
        "bishkred": "existing_credits",
        "beruf": "job",
        "pers": "dependents",
        "telef": "telephone",
        "gastarb": "foreign_worker",
        "kredit": "default"
})

# %%
df.columns
# Out:
# Index(['checking_account', 'loan_duration', 'credit_history', 'loan_purpose',
#        'credit_amount', 'savings_account', 'employment_duration',
#        'installment_rate', 'personal_status', 'guarantors',
#        'residence_duration', 'assets', 'age', 'other_credits', 'housing',
#        'existing_credits', 'job', 'dependents', 'telephone', 'foreign_worker',
#        'default'],
#       dtype='str')

# %%
df["default"].value_counts()
# Out:
# default
# 1    700
# 0    300
# Name: count, dtype: int64

# %%
df.groupby("default")["credit_amount"].mean()
# Out:
# default
# 0    3938.126667
# 1    2985.442857
# Name: credit_amount, dtype: float64
